# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path().resolve().parent))

# %%
from core import MDCrow

# %%
#openai/gpt-oss-20b
llm_var = "openai/gpt-oss-20b"

# %%
agent = MDCrow(model = llm_var)

# %%
agent.run("Download the PDB file for protein 1LYZ")
# Out:
# PDB file found with this ID: 1LYZ
# AgentRunOutput(4 messages)

# %%
agent.run("What file did you download?")
# Out:
# AgentRunOutput(6 messages)
